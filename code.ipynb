# %% [markdown]
# # Project Notebook
#
# This notebook is set up to use the repo-local Python environment.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\hario\sidekick\.venv\Scripts\python.exe
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %%
from pathlib import Path

project_dir = Path.cwd()
venv_dir = project_dir / '.venv'
print(f'Project directory: {project_dir}')
print(f'Virtual environment exists: {venv_dir.exists()}')
# Out:
# Project directory: c:\Users\hario\sidekick
# Virtual environment exists: True

# %%
import sys
from pathlib import Path

project_dir = Path.cwd()
venv_dir = project_dir / '.venv'
print(f'Active Python: {sys.executable}')
print(f'Project directory: {project_dir}')
print(f'Virtual environment exists: {venv_dir.exists()}')
# Out:
# Unable to copy 'C:\\Program Files\\Python314\\Lib\\venv\\scripts\\nt\\venvlauncher.exe' to 'c:\\Users\\hario\\sidekick\\.venv\\Scripts\\python.exe'
# Created .venv in c:\Users\hario\sidekick
